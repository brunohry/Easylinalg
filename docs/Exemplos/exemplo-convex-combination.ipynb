# %%
using EasyLinalg

# %% [markdown]
# # Points

# %%
p1 = Point2D(1, 1)
Draw(p1)

# %%
p2 = Point2D(10, 10)
Draw(p2)

# %%
Draw(convex_combination([p1, p2], 0.1))

# %%
p3 = Point3D(1, 1, 1)
Draw(p3)

# %%
p4 = Point3D(10, 10, 10)
Draw(p4)

# %%
Draw(convex_combination([p3, p4], 0.1))

# %% [markdown]
# # Setas

# %%
s1 = Arrow2D(1,0)
Draw(s1)

# %%
s2 = Arrow2D(0,2)
Draw(s2)

# %%
Draw(convex_combination([s1, s2], 0.1))

# %%
s3 = Arrow3D(1,0,1)
Draw(s3)

# %%
s4 = Arrow3D(0,1,-1)
Draw(s4)

# %%
Draw(convex_combination([s3, s4], 0.1))

# %% [markdown]
# # Signal

# %%
sg1 = SignalBuildU(cos, -10:0.1:10)
Draw(sg1)

# %%
sg2 = SignalBuildU(sin, -10:0.1:10)
Draw(sg2)

# %%
Draw(convex_combination([sg1, sg2], 0.1))

# %% [markdown]
# # Image

# %%
i1 = Image("bola.jpg")
Draw(i1)
# Out:
# 443×456 Array{RGB,2} with eltype ColorTypes.RGB:
#  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(0.996,0.996,0.996)
#  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  ⋮                       ⋱  ⋮
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
# ...

# %%
i2 = Image("quadrado.jpg")
Draw(i2)
# Out:
# 443×456 Array{RGB,2} with eltype ColorTypes.RGB:
#  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(0.988,0.988,0.988)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(0.996,0.996,0.996)
#  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(0.988,0.988,0.988)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(0.996,0.996,0.996)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  ⋮                       ⋱  ⋮
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)     RGB{N0f8}(1.0,1.0,1.0)
# ...

# %%
Draw(convex_combination([i1, i2], 0.1))
# Out:
# 443×456 Array{RGB,2} with eltype ColorTypes.RGB:
#  RGB{Float64}(1.0,1.0,1.0)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(0.996078,0.996078,0.996078)
#  RGB{Float64}(1.0,1.0,1.0)  …  RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,1.0,1.0)  …  RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
#  ⋮                          ⋱  ⋮
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
# ...

# %%
Draw(convex_combination([i2, i1], 0.1))
# Out:
# 443×456 Array{RGB,2} with eltype ColorTypes.RGB:
#  RGB{Float64}(1.0,1.0,1.0)  …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(0.988235,0.988235,0.988235)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(0.996078,0.996078,0.996078)
#  RGB{Float64}(1.0,1.0,1.0)  …  RGB{Float64}(0.988235,0.988235,0.988235)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(0.996078,0.996078,0.996078)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,1.0,1.0)  …  RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
#  ⋮                          ⋱  ⋮
#  RGB{Float64}(1.0,1.0,1.0)     RGB{Float64}(1.0,1.0,1.0)
# ...
