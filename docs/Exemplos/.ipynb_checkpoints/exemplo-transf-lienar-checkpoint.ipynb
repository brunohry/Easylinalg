# %%
using EasyLinalg

# %% [markdown]
# ## Transormação Linear de relefexão
# Precisamos da ajuda do joão apra escrever esse texto

# %%
A = Point2D(1,2)
Draw(A)

# %%
B = [1 0;
     0 -1]
C = A * B
Draw(C)

# %%
Draw(A, false)
Draw(C, false)

# %%
teste = Image("eniac.jpg")
Draw(teste)
# Out:
# 1280×1920 Array{RGB,2} with eltype ColorTypes.RGB:
#  RGB{N0f8}(0.224,0.231,0.22)   …  RGB{N0f8}(0.094,0.094,0.094)
#  RGB{N0f8}(0.227,0.235,0.224)     RGB{N0f8}(0.094,0.094,0.094)
#  RGB{N0f8}(0.227,0.235,0.224)     RGB{N0f8}(0.094,0.094,0.094)
#  RGB{N0f8}(0.224,0.231,0.22)      RGB{N0f8}(0.094,0.094,0.094)
#  RGB{N0f8}(0.22,0.227,0.216)      RGB{N0f8}(0.09,0.09,0.09)
#  RGB{N0f8}(0.216,0.224,0.212)  …  RGB{N0f8}(0.086,0.086,0.086)
#  RGB{N0f8}(0.22,0.227,0.216)      RGB{N0f8}(0.082,0.082,0.082)
#  RGB{N0f8}(0.224,0.231,0.22)      RGB{N0f8}(0.078,0.078,0.078)
#  RGB{N0f8}(0.224,0.231,0.22)      RGB{N0f8}(0.09,0.09,0.09)
#  RGB{N0f8}(0.212,0.22,0.208)      RGB{N0f8}(0.094,0.094,0.094)
#  RGB{N0f8}(0.22,0.227,0.216)   …  RGB{N0f8}(0.094,0.094,0.094)
#  RGB{N0f8}(0.235,0.243,0.231)     RGB{N0f8}(0.098,0.098,0.098)
#  RGB{N0f8}(0.239,0.247,0.235)     RGB{N0f8}(0.102,0.102,0.102)
#  ⋮                             ⋱
#  RGB{N0f8}(0.973,0.973,0.973)     RGB{N0f8}(0.098,0.098,0.098)
# ...

# %%
Draw(teste * B)
# Out:
# 1280×1920 Array{RGB,2} with eltype ColorTypes.RGB:
#  RGB{Float64}(0.407843,0.407843,0.407843)     …  RGB{Float64}(0.803922,0.803922,0.796078)
#  RGB{Float64}(0.0941176,0.0941176,0.0941176)     RGB{Float64}(0.223529,0.231373,0.219608)
#  RGB{Float64}(0.0941176,0.0941176,0.0941176)     RGB{Float64}(0.227451,0.235294,0.223529)
#  RGB{Float64}(0.0941176,0.0941176,0.0941176)     RGB{Float64}(0.227451,0.235294,0.223529)
#  RGB{Float64}(0.0941176,0.0941176,0.0941176)     RGB{Float64}(0.223529,0.231373,0.219608)
#  RGB{Float64}(0.0901961,0.0901961,0.0901961)  …  RGB{Float64}(0.219608,0.227451,0.215686)
#  RGB{Float64}(0.0862745,0.0862745,0.0862745)     RGB{Float64}(0.215686,0.223529,0.211765)
#  RGB{Float64}(0.0823529,0.0823529,0.0823529)     RGB{Float64}(0.219608,0.227451,0.215686)
#  RGB{Float64}(0.0784314,0.0784314,0.0784314)     RGB{Float64}(0.223529,0.231373,0.219608)
#  RGB{Float64}(0.0901961,0.0901961,0.0901961)     RGB{Float64}(0.223529,0.231373,0.219608)
# ...

# %%
B2 = [1 0;
     1 1]
# Out:
# 2×2 Matrix{Int64}:
#  1  0
#  1  1

# %%
Draw(teste * B2)
# Out:
# 3200×1920 Array{RGB,2} with eltype ColorTypes.RGB:
#  RGB{Float64}(0.407843,0.407843,0.407843)     …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                       RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                       RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                       RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                       RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                    …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                       RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                       RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                       RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                       RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                    …  RGB{Float64}(0.0,0.0,0.0)
#  RGB{Float64}(0.0,0.0,0.0)                       RGB{Float64}(0.0,0.0,0.0)
# ...
